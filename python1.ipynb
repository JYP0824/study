# %% [markdown]
# <a href="https://colab.research.google.com/github/JYP0824/study/blob/main/python1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
텍스트 셀 <undefined>
# %% [markdown]
* in 연산자

bool 타입 연산자
확인하고자 하는 데이터가  있으면 True, 없으면 False 반환
반대는 not in

코드 셀 <undefined>
# %% [code]
a = [1, 2, 3, 4, 5]

if 1 in a:
    print("1, exist")
else:
    print("1 not exist")
    
print(2 in a)
print(7 in a)

텍스트 셀 <undefined>
# %% [markdown]
# Loops

텍스트 셀 <undefined>
# %% [markdown]
for 반복문에서 in을 사용하는 것은 위의 예시와 다름

코드 셀 <undefined>
# %% [code]
a = [1, 2, 3, 4, 5]
for val in a:
    print(val)

코드 셀 <undefined>
# %% [code]
a = [1, 2, 3, 4, 5]

for num in a:
    print(num, end=' ')

텍스트 셀 <undefined>
# %% [markdown]
리스트 안의 숫자를 모두 곱하기

코드 셀 <undefined>
# %% [code]
a = [1, 2, 3, 4, 5]
mul = 1

for math in a:
    mul *= math
print(mul)

코드 셀 <undefined>
# %% [code]
s = 'HeeELllLoO'
msg = ' '

for char in s:
    if char.isupper():
        print(char, end= ' ')

텍스트 셀 <undefined>
# %% [markdown]
* .isupper()

문자열에서 대문자만 추출

* .islower()

문자열에서 소문자만 추출
* .upper()

문자열을 대문자로 전환

* .lower()

문자열을 소문자로 전환

코드 셀 <undefined>
# %% [code]
a = 1
for i in range(5):
    print(a)
    a += 1

텍스트 셀 <undefined>
# %% [markdown]
range()를 통해 반복 횟수 정함

코드 셀 <undefined>
# %% [code]
i = 0
while i < 10:
    print(i, "회 반복")
    i += 1

코드 셀 <undefined>
# %% [code]
squares = [n**2 for n in range(10)]
squares

텍스트 셀 <undefined>
# %% [markdown]
파이썬에서의 for문은 자동으로 +1씩 되나봄

체크용 프로그램

코드 셀 <undefined>
# %% [code]
for i in range(10):
    print(i)

텍스트 셀 <undefined>
# %% [markdown]
>요소의 조작
* .append()

선택된 요소의 마지막에 새로운 요소 추가

* .prepend()

선택된 요소의 첫번째에 새로운 요소 추가

* .appendTo()

선택된 요소를 해당 요소의 마지막에 추가

* prependTo()

선택된 요소를 해당 요소의 첫번째에 추가

> 기존 요소의 외부에 추가
* .before()

선택한 요소의 바로 앞에 새로운 요소 추가

* .after()

선택한 요소의 바로 뒤에 새로운 요소 추가

* .insertBefore()

선택한 요소를 해당 요소의 앞쪽에 추가

* .insertAfter()

선택한 요소를 해당 요소의 뒤쪽에 추가

> 기존 요소를 포함하는 요소의 추가
* .wrap()

선택한 요소를 포함하는 새로운 요소 추가

* .wrapAll()

선택한 모든 요소를 포함하는 새로운 요소 추가

* .wrapInner()

선택한 요소에 포함되는 새로운 요소 추가

> 기존 요소의 내부 변경
* .html()

해당 요소의 HTML콘텐츠를 반환하거나 설정

* .text()

해당 요소의 텍스트 콘텐츠를 반환하거나 설정

코드 셀 <undefined>
# %% [code]
squares = []
for n in range(10):
    squares.append(n**2)
    
print(squares)

코드 셀 <undefined>
# %% [code]
pla = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']
pla = [planet for planet in pla if len(planet) < 6]
pla

코드 셀 <undefined>
# %% [code]
def count_num(num):
    n = 0
    for num in nums:
        if num < 0:
            n += 1
    return n

코드 셀 <undefined>
# %% [code]
def count_num(nums):
    return len(num for num in nums if (num < 0))

텍스트 셀 <undefined>
# %% [markdown]
# Strings and Dictations

코드 셀 <undefined>
# %% [code]
x = 'a'
y = 'a'

x == y

코드 셀 <undefined>
# %% [code]
'\'Pluto\'s a planet'

텍스트 셀 <undefined>
# %% [markdown]


텍스트 셀 <undefined>
# %% [markdown]
\'      '

\"      "

\\      \

\n     
1\n2 3
        
        1
        
        2 3

코드 셀 <undefined>
# %% [code]
hello = "hello \n world"
print(hello)

코드 셀 <undefined>
# %% [code]
triplequoted_hello = """hello
world"""
print(triplequoted_hello)
triplequoted_hello == hello

코드 셀 <undefined>
# %% [code]
print("hello")
print("world")
print("hello", end='   ')
print("pluto", end='')

코드 셀 <undefined>
# %% [code]
planet = ['pluto aa']
print(planet [0])
print(planet[3:])
print(len(planet))
planet.append('a')
planet

텍스트 셀 <undefined>
# %% [markdown]
**.append()같은 함수 사용 시 list [] 형태여야함 문자열일 경우 에러 발생**

코드 셀 <undefined>
# %% [code]
planet = 'pluto'
[chr+'!' for chr in planet if len(planet) < 7]

텍스트 셀 <undefined>
# %% [markdown]
* .index()
몇번째인지 알려줌

* .startswith()
뭐로 시작하는지 알려줌

* .split()
문자열을 단어로 분리

* .join()
매개변수로 들어온 ['a', 'b', 'c']식의 리스트를 'abc'의 문자열로 합쳐서 반환
'_'.join(['a', 'b', 'c']라 하면 'a_b_c'식으로 반환

코드 셀 <undefined>
# %% [code]
str = 'hello world'
if str.startswith('hello'):
    print("start with hello")
if not str.startswith('world'):
    print("그거로 시작 안함")
if str.endswith('world'):
    print("정답")
    
strings =str.split()
list = []
for word in strings:
    if word.startswith('world'):
        list.append(word)
        
print(list)

코드 셀 <undefined>
# %% [code]
datestr = '1956-01-31'
year, month, day = datestr.split('-')

print(year)

코드 셀 <undefined>
# %% [code]
datestr = '1956-01-31'
'     '.join(datestr)

코드 셀 <undefined>
# %% [code]
planet = 'pluto'
position = 9

"{} aaa {}".format(planet, position)

텍스트 셀 <undefined>
# %% [markdown]
* .format()

문자열 포메팅

코드 셀 <undefined>
# %% [code]
a = 2
b = 3
s = '구구단 {} x {} = {}'.format(a, b, a*b)
print(s)

코드 셀 <undefined>
# %% [code]
num = {'one':1, 'two':2, 'three':3}

num['one']
num['eleven'] = 11
print(num['eleven'])
num['planet'] = 'pluto'
print(num['planet'])
'planet' in num
'pluto' in num

for k in num:
    print('{}: {}'.format(k, num[k]))

코드 셀 <undefined>
# %% [code]
nums = {'one':1, 'two':2, 'three':3}

for num, su in nums.items():
    print("{}는 {}".format(num.rjust(3), su))

텍스트 셀 <undefined>
# %% [markdown]
* .items()

딕셔너리의 키, 값 쌍 얻기

* .rjust()
오른쪽으로 공백의 수, 공백을 메워줄 문자를 넣음

코드 셀 <undefined>
# %% [code]
car = {"name" : "BMW", "price": 7000}
for key, val in car.items():
    print("차종 {}, 가격: {}".format(key, val))

텍스트 셀 <undefined>
# %% [markdown]
**dictionary만들 때 중괄호[]아니라 대괄호{}사용 주의**

텍스트 셀 <undefined>
# %% [markdown]
# Learning with External Libraries

텍스트 셀 <undefined>
# %% [markdown]
* import
다른 프로그램으로부터 데이터를 불러옴

import 모듈 // 모듈 전체를 불러옴

from 모듈 import 이름 // 모듈 내에서 필요한 부분만 불러옴

코드 셀 <undefined>
# %% [code]
import math as mt

print(math.log(32, 2))

mt.pi

코드 셀 <undefined>
# %% [code]
from math import *
from numpy import *

print(pi, log(32, 2))

텍스트 셀 <undefined>
# %% [markdown]
math, numpy 모듈 모두 log함수가 있지만 의미체계가 다름, math를 불러온 후 numpy에서 불러왔기 때문에 numpy의 *로 덮어짐

코드 셀 <undefined>
# %% [code]
import numpy
print('numpy.random is a ', type(numpy.random))
print('it contains names such as', dir(numpy.random)[-20:])

텍스트 셀 <undefined>
# %% [markdown]
* dir()

어떤 객체를 인자로 넣어주면 해당 객체가 어떤 변수와 메소드를 가졌는지 나열해줌

텍스트 셀 <undefined>
# %% [markdown]
* .random()

0이상 1 미만의 실수 난수 생성

* .randint()

start이상 stop이하의 범위의 정수 난수 생성

* .randrange()

low 이상 high이하의 범위에서, low에 step을 더해간 범위 내에서 정수 난수 생성(일련의 규칙을 갖는 수열 중 무작위 추출)

코드 셀 <undefined>
# %% [code]
import random

dice = numpy.random.randint(low = 1, high = 6, size = 10)
print(dice)

random.randrange(0, 100, 10)

텍스트 셀 <undefined>
# %% [markdown]
randrange: 0~100 중에서 10의 단위로 더해진 숫자 중 무작위 추출

텍스트 셀 <undefined>
# %% [markdown]
* mean()

평균 계산

* .var()

분산 계산

* .std()

표준편차 계산


* .tolist()

같은 레벨의 데이터끼리 묶어줌

코드 셀 <undefined>
# %% [code]
import numpy

list = [[1, 2, 3], [4, 5, 6]]

x = numpy.asarray(list)
print('list = {} = {}'.format(list, x))

코드 셀 <undefined>
# %% [code]
import tensorflow as tf

a = tf.constant(1)
b = tf.constant(1)

a + b

코드 셀 <undefined>
# %% [code]
def addthree(num):
    num += 3
    return num

print(addthree(3))

코드 셀 <undefined>
# %% [code]
def pay(num):
    pay_pretax = num * 15
    pay_aftertax = pay_pretax *(0.9)
    return pay_aftertax

print(pay(10))

코드 셀 <undefined>
# %% [code]
def print_hello():
    print("hello")
    
print_hello()
# Out:
#   File "<ipython-input-1-a028ffba629b>", line 106
#     파이썬에서의 for문은 자동으로 +1씩 되나봄
#                        ^
# SyntaxError: invalid decimal literal
