# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 해당 수식을 풀기 위해 역행렬을 이용하게 된다
#
# ### identity Matrix (항등 행렬)
#
# 기본적으로 정사각 행렬이며, 가운데 값은 1이며 나머지는 0인 행렬
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 항등 행렬은 어떤 벡터와 곱함에도 자기자신을 유지함
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Inverse Matrix (역행렬)
#
# 역행렬은 항상 정사각행렬만을 대상으로 함
#
# Matrix A 어디에 곱하던 항등행렬을 만들어냄
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# (정사각행렬의 경우) 역행렬 구하는 수식

# %% [markdown]
#  직사각행렬의 경우 양 방향 중 어디로 곱하든 항등행렬을 만들어낸다는 조건 중 한 가지밖에 부합하지 못함
#
#  그러므로 역행렬은 정사각행렬에서만 존재하게 됨
#
#  직사각행렬에서는 한 쪽의 관계만 만족함

# %% [markdown]
# ![image.png](attachment:image.png)
#
# **역행렬을 통해 방정식 풀기**

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 역행렬이 존재할 경우
# ![image.png](attachment:image.png)
#
# 다음 수식을 통해 수식을 구할 수 있으나 역행렬이 존재하지 않을경우
# ![image-2.png](attachment:image-2.png)
# 0 이 되는 경우 (ad = bc)
# ![image-3.png](attachment:image-3.png)
# 라고 부르게  된다

# %% [markdown]
# det A의 값이 0이 아닐 경우 역행렬 존재
# (방정식의 해가 1개)
#
#
# def A의 값이 0일 경우 역행렬이 존재하지 않음

# %% [markdown]
# 역행렬이 없는 경우 (방정식의 해가 무수히 많거나 / 없음)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# 수집한 샘플의 수보다 샘플을 나타내는 feature의 수가 더 많은 경우 해가 무수히 많음
#
# (머신러닝)Regularazation 적용 // 무수히 많은 해 중 가중치를 가장 적게 부여하는 해를 솔루션으로 적용
#
#
# ![image-3.png](attachment:image-3.png)
# 미지수의 수보다 방정식의 수가 더 많은 경우 해가 없음
# ![image-4.png](attachment:image-4.png)
