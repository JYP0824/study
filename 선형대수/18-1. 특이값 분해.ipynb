# %% [markdown]
# ### Singular Value Decomposition (SVD)
#
# 정사각 행렬이 아닌 직사각 행렬을 대산으로 한다
#
# ![image.png](attachment:image.png)
#
# 주어진 matrix를 3개의 matrix로 분해
#
# eigen decomposition에서는 ![image-2.png](attachment:image-2.png)
# V가 역행렬관계에 D가 diagonal matrix여야 한다는 조건
#
# SVD에서는 U와 V라는 matrix는 각각 orthonormal한 column을 가지는 matrix이다 (V는 transpose 되어있으므로 row vector가 normal)
#
# 시그마는 diagonal entry = 1이 된다

# %% [markdown]
# m > n인 경우
#
# ![image.png](attachment:image.png)

# %% [markdown]
# m = 5 / n = 3일경우
#
# u1 ~ um까지 전부 orthonormal vector이며, 5-dimensional vector
#
# Vt는 3x3 matrix이며, row vector가 길이가 1이고 수직
#
# 가운데의 matrix는 주어진 입력 matrix와 크기는 동일하지만 diagonal entry만 non zero인 형태이다

# %% [markdown]
# ![image.png](attachment:image.png)
#
# U은 재료벡터로 쓰이며, 시그마의 column이 선형 변환의 coefficient로 쓰인다
#
# ![image-5.png](attachment:image-5.png)
#
# 각 column별로 scaling
#
# 첫번째 column에 3배 / 2번째 column에 5배..

# %% [markdown]
# 그 후 Vt와 곱하게 된다
#
#
# ![image.png](attachment:image.png)
#
# 서로 pair를 이루게 된다
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# 5x5라는 5개의 orthonormal한 column 벡터 (U)
#
# diagonal matric에서는 5x3이기에 총 5개의 재료벡터가 있었지만
# 곱해지는 matrix는 3개가 된다
#
# 결과값은 3개의 outer product의 sum으로 표현이 된다

# %% [markdown]
# ![image.png](attachment:image.png)
# 이 되어
# ![image-2.png](attachment:image-2.png)
# 크기를 가진 matrix가 된다

# %% [markdown]
# 이 때 U, V matrix가 orthonormal한 column을 가지는데, !
# ![image-2.png](attachment:image-2.png)
# 오른쪽의 matrix의 경우 row벡터를 재료벡터로 사용하며, 각각의 row 벡터들이 행렬곱의 첫번째 row벡터를 만들어내는 선형결합의 계수로 쓰인다

# %% [markdown]
# 왼쪽 matrix가 diagonal matrix이기에 결과적으로 오른쪽 matrix와 동일한 형태의 matrix가 나오게 되며, 선형결합의 상수배가 ![image.png](attachment:image.png)이러한 형태의 matrix가 나온다

# %% [markdown]
# 결과적으로 matix U와 합쳐진 matrix의 곱이 된다
#
# 입력 matrix의 각각의 column은 두 덩어리로 분해한![image.png](attachment:image.png) matrix 중 왼쪽 matrix의 각각의 column들의 linear combination으로 입력 matrix의 colum을 표현할 수 있다
#
# matrix A의 column들을 선형 결합을 통해 표시해주기 때문에 왼쪽 벡터를 column들의 basis 벡터라 볼 수 있다
#
# 주어진 입력 matrix들의 column들을 만들어내는데 쓸 수 있는 재료벡터들을 3개의 column벡터들로 구성하게 되며, 왼쪽 matrix는 orthonormal하기에 길이가 1이고, 수직이다
#
# 왼쪽 matrix가 orthonormal한 column들을 가지는 matrix이기에 이 column들이 A에 대한 모든 column들을 선형결합으로 표현할 수 있어야 하며, orthonormal한 column들을 그람-슈미츠 / QR factorization과 같은 방식으로 뽑아낸다

# %% [markdown]
# ![image.png](attachment:image.png)를 transpose하게되면 ![image-2.png](attachment:image-2.png)가 된다
#
# V에서의 row vector가 V에서 column 벡터로 오게된다
#
# 그 후 그람-슈미츠 orthogonalize화 하면 V에 해당하는 orthonormal한 column들을 얻어낼 수 있다

# %% [markdown]
# orthonormal한 matrix인 U, V는 복원할 수 있지만 orthonormal한 basis가 항상 unique인지 여러 choice일 것인가
#
# 같은 subspace를 span하지만 orthonormal한 basis도 여러개가 있다
#
# 여러 choice 중 특정 조건을 만족하는 orthonormal한 basis를 갖는다
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# column들을 재료벡터로 쓸 수 있는 basis vector를 orthonormal basis로 뽑아야 하고, row들을 만들어낼 수 있는 벡터들의 orthonormal한 버전을 만들어내야 하는데,
#
# ![image-3.png](attachment:image-3.png)
#
# u에서의 1번째 벡터와 v에서의 첫번째 벡터가 연결관계에 있게 된다

# %% [markdown]
# v에서의 첫번째 벡터를 뽑아서 A와 곱하면 2차원 벡터가 3차원 벡터로 변환되는데, 3차원 벡터가 길이가 1인 벡터의 상수배로 나타나고, 길이가 1인 벡터는 u를  구성할 때의 첫번째 orthonormal한 벡터가 된다
# ![image.png](attachment:image.png)
# V에서 나온 각각의 orthonormal한 벡터들을 변환시켜 3차원 벡터로 만들었더니 3차원 벡터들도 수직한 관계에 있는 벡터들도 변환이 된다

# %% [markdown]
# diagonalization을 배울 때 봤었던 유도과정
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# Vt를 transpose해 row벡터들을 column 벡터로 가져옴

# %% [markdown]
# U와 V가 SVD에서의 조건을 만족하는 orthonormal한 column벡터를 가지는 matrix이며, V가 정사각 행렬인 경우 V의 역행렬은 V의 transpose
# ![image.png](attachment:image.png)
#
# 만 키시면 원래 있던 orthonormal한 column들을 가지는 정사각 행렬의 역행렬이 된다
#
# ![image-2.png](attachment:image-2.png)
# 양쪽 식에 곱해
#
# ![image-3.png](attachment:image-3.png)
#
# 최종 수식을 얻을 수 있다
