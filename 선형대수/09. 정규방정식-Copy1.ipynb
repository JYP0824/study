# %% [markdown]
# ![image.png](attachment:image.png)
#
# 역행렬이 있을 경우 x^이라는 최적의 solution을 찾을 수 있다
#
# 역행렬이 없다면 해는 무수히 많거나 없다
#
# ![image-2.png](attachment:image-2.png)
#
# 해가 무수히 많음
# ![image-3.png](attachment:image-3.png)
# 해가 없음

# %% [markdown]
# ![image.png](attachment:image.png)
#
# feature 갯수만큼의 정사각행렬을 얻어낸다 (A^T*A)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)
#
# 수식은 모두 스칼라값을 나타냄
#
# ||b-Ax||가 최소라면 ||b-Ax||^2도 같은 조건에서 최소이다

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Transpose시 순서가 바뀜

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 그 후 x에 대해 편미분
#
# ex)![image-2.png](attachment:image-2.png)
#
# a라는 column 벡터가 나옴

# %% [markdown]
# ![image.png](attachment:image.png)
# 미분 시 위의 예시와 같이 -A^Tb가 된다

# %% [markdown]
# ![image-4.png](attachment:image-4.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 수식을 푼 결과 앞서 봤던 Normal equation과 같아짐

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 역행렬이 없을 때에는 Normal equation 상에서는 해가 없는 경우는 없기 때문에 해가 무수히 많은 경우가
# ![image.png](attachment:image.png)
# 식이 역행렬이 없는 경우와 동일한 상황이 된다

# %% [markdown]
# 3개의 column 벡터가 선형독립일 경우 역행렬이 존재하고, 선형의존이면 역행렬이 존재하지 않음
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)
#
# 수선의 발은 항상 존재(해가 항상 존재)하며, 수선의 발은 항상 unique한 point로 존재
#
# 즉, 선을 그었을 때 앞선 모든 벡터와 수직임을 만족하는 수선의 발은 한 점밖에 없다
#
# 이 때 b^을 표현하기 위해 x^이 유일한 선형결합 계수일 경우 해가 하나, b^을 나타내는 여러 선형 계수가 존재하면 해가 무수히 많음

# %% [markdown]
# ![image.png](attachment:image.png)
#
# b^을 표현하기 위한 평행사변형의 choice가 하나(선형 독립) / 많다 (선형 의존) 또한 이 경우 A^T*A의 역행렬이 존재하지 않는다

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# data가 feature보다 많이 쌓여 있는 경우 선형 독립인 경우가 많음
#
# A^T*A도 역행렬을 거의 가지게 된다
