# %% [markdown]
# 중복이 되는 정보를 추출하게 되면, 그 모듈을 후처리를 통해 수직인 벡터로 바꿈으로서 projection의 값들이 서로 영향을 받지 않고, 중복이 없도록 하는 형태의 linearly independent한 벡터를 orthogonal한 벡터 세트로 만들어내는 과정

# %% [markdown]
# ## 그람-슈미츠 직교화

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# 내적이 0 이 아님(수직이 아닌 벡터)

# %% [markdown]
# 두 벡터를 수직하면서 길이가 1인 벡터로 만드는 변환

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 먼저 길이가 1인 u1벡터를 구한 후 v2벡터를 u1벡터에 수직으로 projection시킨 벡터를 찾는다
#
#
# ![image.png](attachment:image.png)
#
# 원점으로 가져와
#
# ![image-2.png](attachment:image-2.png)
#
# 서로간 수직인 u2벡터로 만든다

# %% [markdown]
# 즉, v2에서 v2에서 u1으로 projection한 성분을 빼면 u2가 구해짐
#
# v2와 길이가 1인 벡터와 내적(길이가 구해짐)을 하고, u1을 곱(방향성)해줘 v2에서 line으로의 projection벡터가 구해진다
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# 길이가 1인 orthonormal한 벡터로 변환
#
# 두 벡터는 앞단의 벡터의 span과 동일

# %% [markdown]
# 또 다른 벡터가 있을 경우
#
# ![image.png](attachment:image.png)
#
# 벡터에 projection한 것을 구해 빼준다
#
# ![image-2.png](attachment:image-2.png)
#
# 그 후 길이가 1이 되도록 normalize해주면, orthonormal한 basis벡터를 구할 수 있게 된다

# %% [markdown]
# ### matrix factorization
#
# original input matrix로의 복원

# %% [markdown]
# 앞의 column벡터를 통한 곱 = v1
#
#
# ![image.png](attachment:image.png)
#
#  두번째 column벡테와의 곱 = v2
#
#  ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 실제 값 구해보기
#
# ![image.png](attachment:image.png)
#
# u1은 v1벡터를 normalize 한 값이므로 첫번째에 나눈 값을 쓰고, 두번째 값은 0으로 채움

# %% [markdown]
# u2의 경우 orthogonal porjection을 구해 normalize를 함

# %% [markdown]
# 이 값이 선형결합에 쓰이는 가중치가 된다
#
#
# 첫 번째 벡터의 경우
#
# ![image.png](attachment:image.png)
#
# 가 되며, u2를 구할 때 normalize할 때 2를 나눠주었기 때문에
#
# ![image-2.png](attachment:image-2.png)
#
# 다음과 같이 계산한다

# %% [markdown]
# 4개의 linearly independent한 column벡터로 이루어진 경우
#
#
# 한줄 한줄 orthonomalize할 때마다  linear combination coefficient를 써줌
#
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)
#
# A는 linearly independent한 column을 갖고 있던 matrix
#
#
# Q는 동일한 column 갯수를 가지며, orthonormal한 basis를 가지는 matrix
#
# R은 triangular한 matrix가 나오게 됨 (orthogonalize하는데 사용된 계수의 집합)
#
#
# **QR factorization**
