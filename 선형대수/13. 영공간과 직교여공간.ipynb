# %% [markdown]
# ## Orthogonal Complement
#
# ![image.png](attachment:image.png)
#
# ### Null Space
#
# Col A (A의 colunmn들에 의해 span되는 subspace)
# Nul A (Ax = 0 형태의 방정식을 만족하는 벡터 x의 집합)
#
# eigen vector, value는 정사각 행렬에서만 따지지만, column space의 경우 직사각 행렬도 되므로, null space도 직사각 행렬에서의 상황을 다룸

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 각각의 row vector(1,2 / 3,4 / 5,6)서로 다른 방향을 가지는 벡터에 모두 수직인 각도를 가지는 (x,y) 벡터를 모은 집합이 matrix A의 null space가 된다

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 디폴트로 column벡터를 다루기 때문에 ![image-2.png](attachment:image-2.png) transpose라고 붙여준다

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 두 column 벡터가 linearly independent(서로 방향이 달라 상수배해도 값이 안나옴)
#
# 이와 같은 형태의 Ax = b 형태의 solution은 homogenious linear system만이 있다. non trivial한 solution은 없다
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# matrix A의 모든 row vector들과 수직이기 위해서는 column space of A와 수직이어야 한다

# %% [markdown]
# 재료벡터들과 수직이면 linear combination으로 표현되는 colum space내의 어떤 점과 항상 수직이 된다
#
#
# ![image.png](attachment:image.png)
#
# 각각이 수직이 되는 조건과 추가된 벡터가 basis벡터의 span에 포함되지 않는 것

# %% [markdown]
# ![image.png](attachment:image.png)
#
# linearly independent / dependent 한 상황을 각도의 개념으로 생각해보면 각도가 linearly dependent한 경우 점이 평면에 들어와 projection 시 이루는 각도가 0도
#
# 1도 만이라도 생길 경우 v3가 평면의 바깥으로 삐져나온 linearly independent
#
# orthogonal은 각도가 90도로 서있는 경우

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 3개의 row 벡터는 2차원 공간을 꽉 채움
#
# 추가해야 할 벡터 x1,x2는 2차원 공간 상에 있으므로 기존 벡터에 linearly dependent하다 (0도)
#
# orthogonal할 가능성(linearly independent)은 아예 없어짐

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# Col space의 전체 집합은 |R의 3차원
#
# Row space는 row 벡터가 span하는 subspace
#
# row vector는 기본적으로 element가 두 개인 2 dimensional vector이기에![image-3.png](attachment:image-3.png)
# |R의 2차원에 있는 벡터 집합

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Row space의 dimension (subspace의 basis vector 수)
#
# 1,2 / 3,4 linearly independent함, 5,6은 두 벡터에 의해 전체가 커버되어 linearly dependent해짐
#
# 즉, 1,2 / 3,4가 basis vector로 볼 수 있다

# %% [markdown]
# ![image.png](attachment:image.png)
# x1,x2를 곱해 0을 만들어주는 x1,x2벡터의 subspace dimension

# %% [markdown]
# 3번째 벡터가 조금이라도 linearly independent하다면 그람-슈미츠 Orthogonalization을 통해 projection시켜 그 벡터 부분을 통해 orthogonal vector를 만들 수 있다
#
# 여기서 2 dimension basis가 전체 dimension을 차지하기에 새로 찾을 수 있는 linearly independent한 벡터는 찾을 수 없다

# %% [markdown]
# ![image.png](attachment:image.png)
#
# [1,2, 3]이라고 하는 row vector
#
# 3차원 상의 벡터
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 그 후 3차원 공간 상에서 linearly independent한 벡터를 하나 더 찾음
#
# 그 후 그람-슈미츠 orthogonalization을 통해 orthogonal한 벡터를 만들어줌
#
# 이를 통해 찾은 기존 basis와 linearly independent한 벡터를 orthogonalize해 x벡터의 subspace dimension을 구할 수 있다

# %% [markdown]
# 가능한 모든 x벡터를 모았을 때 subspace에서의 dimension은 2가 된다
# 1,2,3 이라는 벡터가 있었고, 두 번째 linearly independent한 벡터를 찾아 orthogonalize하고, 또 linearly independent한 벡터를 찾아 orthogonalize하면 더 이상 찾을 순 없음  (3차원)
#
# ![image.png](attachment:image.png)
#
# 즉, span으로 이루어진 row space는 1차원이며, Nul space에서의 basis는 3-1 = 2개(차원)
#
# ![image-2.png](attachment:image-2.png)
#
# 즉, Row space가 선 하나면, Nul space dimention(basis vector)2가 된다

# %% [markdown]
# ![image.png](attachment:image.png)
#
# n dimentional vector에서는 n개의 basis vector를 찾을 수 있듯이
#
# ![image-2.png](attachment:image-2.png)
#
# 3차원 상에서 row space에서의 basis vector는 하나라 dimension이 1이면, nul space에서의 basis로 쓰는 vector는 2개까지 찾을 수 있다
#
# ![image-3.png](attachment:image-3.png)
# **Rank Theorem**

# %% [markdown]
# Column space 상에서는
#
# ![image-3.png](attachment:image-3.png)
#
# row로 만들어주고, 0이 되도록 하는 column space에 수직인 벡터들에 의해 구성된 subspace의 basis는 1개가 된다
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Nulspace of A는 Rowspace of A에 수직인 형태의 subspace
#
# Nulspace of A transpose는 A의 Column space의 모든 vector들과 수직인 벡터

# %% [markdown]
# ![image.png](attachment:image.png)
#
# row space는 2차원인데, rowspace가 다 가져갔으므로 A의 null space는 0차원(0벡터밖에 없다)

# %% [markdown]
# null space가 subspace인 이유
#
# subspace는 항상 span의 basis vector로 나타낼 수 있음
# ![image.png](attachment:image.png)
# null space는 위의 수식을 만족하는 모든 벡터의 집합

# %% [markdown]
# ![image.png](attachment:image.png)
# A에서의 column이 2개일 경우 벡터 x는 2개의 벡터와 수직이어야 함
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 위의 식을 만족하는 벡터 x, y (Null space)
#
# a,b라는 상수에 linear combination 시 여전히 null space에 포함되어 있는가 (선형결합에 닫혀있는가)를 통해 subspace라는 것을 알 수 있음
#
# 이 벡터가 x자리에 들어갔을 때 0벡터가 만들어지면 만족
#
# x, y는 이미 두 벡터와 수직이기 때문에 두 벡터에 수직인 벡터를  linear combination한 벡터를 내적해도 똑같이 0벡터를 만들어낸다
#
# 즉, subspace가 된다
