# %% [markdown]
# eigenvalue와 vector를 구할 때
# ![image.png](attachment:image.png)
#
# 위의 수식을 만족해야 하기 때문에 null space를 사용하게됨

# %% [markdown]
# 람다가 정해졌다면 matrix에 대한 null space를 찾으면, null spcae의 non-zero vector들이 찾고자하는 eigen vector가 된다.
#
# 주어진 matrix A에 대해 람다(eigen value = 3)만큼 들어냄
# ![image.png](attachment:image.png)
#
# 여기서 나온 matrix가
#
# ![image-4.png](attachment:image-4.png)
# 만약 이렇게 나올 경우 여기서 만족하는 벡터 x는 row vector와 수직이어야 하는데, 3개의 벡터가 1번째 벡터에 linearly dependent한 벡터
#
# Row A는 1차원이다
#
# eigen vector (x)는 2차원에 존재할 수 있다

# %% [markdown]
# ![image.png](attachment:image.png)
#
# eigen value를 사용하면 column 상에서 linearly independent하게 만들어주는데, row별로 봤을 때 row가 1차원일 경우 3이라는 eigen value는 2차원의 eigen vector를 가진다

# %% [markdown]
# ![image.png](attachment:image.png)
#
# matrix A에 대한 eigen value = 8
#
# 뺐더니 두 vector는 서로 linearly dependent한 벡터가 됐고, eigen vector는 1,1의 상수배로 표현된다.

# %% [markdown]
# 여기서 1,1이랑 linearly independent한 벡터를 찾기 위해 ![image.png](attachment:image.png)
# row space로 보면 두 벡터에 수직인 벡터를 찾아야 함
#
# 두 벡터는 1차원의 line이 되며, 전체 차원은 2차원이므로 1차원이 남음
#
# ![image-2.png](attachment:image-2.png)
#
# 여기서 1차원에서의 basis vector를 이미 1,1로 찾았음, 이외에 linearly independent한 벡터는 이 경우 찾을 수 없다

# %% [markdown]
# ![image.png](attachment:image.png)
#
# linearly dependent한 두 column 벡터를 갖게 됨 (non trivial한 solution을 가짐)
#
# 그 벡터를 찾기 위해![image-2.png](attachment:image-2.png)
#
# 두 벡터에 의해 span되는 subspace에 수직인 벡터를 찾아야 하는데, ![image-3.png](attachment:image-3.png)
#
# 이 eigen value에 해당하는 eigen vector를 구할 수 있다

# %% [markdown]
# eigen value 찾기
#
# ![image-2.png](attachment:image-2.png)
#
# 수식을 통해 만들어지는 matrix
#
# ![image.png](attachment:image.png)
#
# 가 linearly dependent한 column이 나와야 x가 non trivial한 solution이 있음

# %% [markdown]
# 2차원의 matrix의 linearly dependent한 vector를 가질 때
#
# (역행렬이 없었을 때)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# determinent of A
#
# matrix에 역행렬이 없을때가 matrix의 column들이 linearly dependent해질때와 동일한 상황이다
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# linearly dependent / independent의 경우 대상이 되는 matrix를 통해 알아낼 수 있음
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
# 정사각 행렬에서도 각각의 column들이 linearly dependent / independent를 따질 수 있다

# %% [markdown]
# 역행렬이 있다 / 없다의 경우 항상 정사각 행렬에서만 볼 수 있음
#
# linearly dependent / independent를 정사각 행렬에서 보게되면, 그 때의 linearly independent한 경우가 역행렬이 있는 경우와 동치이며, linearly dependent한 경우 역행렬이 없는 경우와 동치이다

# %% [markdown]
# eigen vector / value를 정사각 행렬을 대상만으로 따지며, 람다값을 뺀 matrix를 linearly dependent한 column이 되도록 만들어주는 것이 목적이며, 정사각 행렬이 역행렬이 존재하지 않도록 만든다는 것과 같은 의미이다
#
# ![image.png](attachment:image.png)
#
# 0이 될 때: 해당 matrix가 역행렬이 없을 때이며, 이 식이 만족되면 column들이 linearly dependent해진다

# %% [markdown]
# 람다를 찾기 위해선 A-람다I의 determinent를 구해 방정식을 풀어 값을 0으로 만드는 람다를 찾게 된다
#
# **Characteristic Equation**  matrix A의 특성방정식

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 이 때 구한 람다 값을![image.png](attachment:image.png)
# 대입하여 null space를 따져 x에 대해 가능한 모든 solution인 eigen vector를 구하면 value값 8과 matching이 되는 페어 관계인 vector가 된다

# %% [markdown]
# 주어진 matrix가 ![image.png](attachment:image.png) 한 line으로 이루어진 row space의 dimension이 1인 경우 eigen vector들이 존재하는 곳은![image-3.png](attachment:image-3.png) 평면이 된다
#
# 그리고 평면에 수직인 벡터 1,2,3이 되며, 평면 상 모든 벡터는 eigen vector가 되며, eigen vector를 만들어낸 람다가 8일 경우![image-4.png](attachment:image-4.png)
# 이 수식을 만족하는 null space를 eigen space라 부르며, 해당하는 값이 8이면 람다가 8에 해당하는 eigen space가 된다
#
# eigen space상에서 아무 벡터를 뽑아 A와 곱하면
# ![image-5.png](attachment:image-5.png)
# 가 나온다
#
# 즉, 방향은 바꾸지 않고, 크기(람다값)만 바꿔준다
#
# eigen space에서 어떤 벡터를 뽑아도 벡터에 matrix A를 곱하면 방향은 유지가 되고, 크기만 8배가 된다
#
# 즉, 다른 방향으로 삐져나온 벡터는 생길수가 없다
