# %% [markdown]
# b가 A의 Column들의 space에 포함되지 않을 경우 solution이 없다

# %% [markdown]
# b는 A의 Column space로 정확한 값을 만들 수 없으므로, 가장 근사한 값을 나타내게 해주는 x벡터를 찾아야 함
#
# 이 때 (Ax) A의 Clumn들에 선형 결합을 한 형태

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# Ax는 항상 A의 Column space 안에 존재해야 한다
#
# 즉, 주어진 b벡터와 A의 column space의 점 중에서 b벡터와 가장 가까운 벡터, 그 때의 x값을 찾아내야 한다

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Col A의 span 바깥에 있는 b와 가장 가까운 곳에 존재하는 b^을 찾는 것이 목표
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ex)해당 solution이 최소의 길이일 경우

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 최소길이가 되기 위한 조건
#
# b^과 임의의 다른 점에서 뻗은 선으로 만들어진 삼각형 내에서 각도가 90을 이뤄하 함

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# 재료벡터와 모두 수직이면 어떤 랜덤한 linear combination이 들어와도 항상 수직을 이루게 된다

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# a벡터와 내적 시 수직일 경우 x(계수값)이 어떤 값이든 항상 0이된다

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 즉, 이 벡터는 column space의 어떤 벡터와도 다 수직을 이룬다

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 즉, 벡터가 column space의 basis인 matrix의 각각의 matrix와 수직이다

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 곱할 시 3차원의 column벡터가 나오며, 그 벡터가 0이어야 한다
#
# ![image-2.png](attachment:image-2.png)
#
#
# 즉, 이 식이 최단거리에서의 점인 b^과 그 때의 x^이 만족해야 하는 방정식이 된다
#
# **(Normal equation)**

# %% [markdown]
# ![image.png](attachment:image.png)
