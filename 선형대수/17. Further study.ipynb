# %% [markdown]
# ![image.png](attachment:image.png)
#
# 언제 matrix A가 diagonalizable한지 안한지
# eigen decomposition이 존재하는지
#
# 선형 독립적인 eigen vector를 뽑아낼 수 있으면 diagonalizable한데
#
# 어느 상황에서 n개의 linearly independent한 eigen vector를 뽑을 수 있는가

# %% [markdown]
# **Geometric multiplicity**
#
#
#
# **algebraic multiplicity**

# %% [markdown]
# ![image.png](attachment:image.png)
# 를 풀어 가능한 eigen value를 뽑아내는데
#
# ![image-2.png](attachment:image-2.png) 형태로 matrix를 만들고 determinent를 구하면
#
# ![image-3.png](attachment:image-3.png) 이렇게 곱한 값을 더한 후 ![image-4.png](attachment:image-4.png)
# 이렇게 곱한 값을 빼낸다

# %% [markdown]
# 이 때 가운데의 3개 값을 곱하면 람다의 3승이 나온다
#
# 즉, 위의 수식에서의 determinent는 n차 다항식이 나오게 되며 =0이 된다
#
# n차 다항식은 n개의 해를 갖고 있다
# ![image.png](attachment:image.png)
#
# 5차식의 경우 모든 다항식은 실수 계수를 갖는 형태로 1차나 2차의 식으로 인수분해된다
#
# 복소수의 범위까지 확장해 5차 방정식은 5개의 근을 갖는데, 실근만으로 국한 시 1개나 3개나 5개가 나오게 된다
#
# 5차식의 det의 실근 최대 갯수는 5개이지만 덜 나올 수 있다
#
# 대부분의 ML에서는 실수만을 다루며, 복소수는 안다룬다

# %% [markdown]
# 입력 matrix eigen value / vector다 실수로 다룬다
#
# 총 5개의 근 중에서 실근이 5개가 안나오면 n개의 linearly independent한 eigen vector도 안나온다
#
# 실근이 5개가 나왔는데, 중근일 경우
#
# ![image.png](attachment:image.png)
#
# 이렇게 존재할 수 있는 eigen vector를 뽑아내는데, eigen space의 basis는 2가 가지는 중근의 갯수까지 나올 수 있다
#
# 3의 경우 최대 1개까지만 나오며, 아예 안나올수는 없다
#
# det = 0은 역행렬이 없도록 강제했다는 것이며, 역행렬이 없다는 것은 linearly dependent한 column이 있다는 것이며, non trivial한 solution이 무조건 하나는 있다는 것을 의미한다
#
# eigen space는 각 특정한 eigen value마다 최소한 1차원 이상의 (1개 이상의 basis)dimension을 가지게 된다

# %% [markdown]
# max값을 달성하면 총 3개의 lienarly independent한 eigen vector를 얻어낼 수 있고, 중근의 eigen space의 dimension이 1일 경우 총 3차원에서 2개의 linearly independent한 eigen vector를 뽑아낼 수 있기에 eigen decomposition이 존재하지 않게 된다

# %% [markdown]
# eigen value값이 다르면 각각의 eigen space는 linearly independent해 둘의 vector는 겹치지 않다
#
# subspace간 basis는 원점만 공유되고 나머지는 공유하지 않음

# %% [markdown]
# A가 중근이 없이 n개의 서로 다은 eigen value를 가지면,
#
# ![image.png](attachment:image.png)
#
# 여기서는 eigen space에서의 basis는 1개씩은 무조건 나와 linearly independent하기에 diagonalizable하다
