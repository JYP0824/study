# %% [markdown]
# **eigen composition**
#
# 주어진 matrix에 대한 정보를 추출해내는 과정
#
# matrix의 특성을 밝혀내는 과정

# %% [markdown]
# 주어진 square matrix A(정사각 행렬)의 eigenvector는 nonzero 벡터이어야 하며, ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# 이 식을 만족해야 한다

# %% [markdown]
# 이런 형태의 벡터 x를 A(matrix)의 eigenvector이다
#
# 주어진 matrix에 대해 eigenvector뿐 아니라 ![image.png](attachment:image.png) eigenvalue라 하는 스칼라 값을 같이 구해야 한다

# %% [markdown]
#  ![image.png](attachment:image.png)
#
#  일반적인 벡터의 변환 (크기와 방향이 모두 바뀜)
#
# 주어진 matrix A에 대한 eigenvector는 A를 통해 변환이 일어난 후의 출력 벡터가 원래 입력 벡터의 상수배로 방향은  변하지 않고, 크기만 바뀌는 것을 뜻한다.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# eigenvector로 대체하기 되면, 계산의 횟수가 6번에서 2번으로 줄어들게 된다

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# facorize
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# 여기서 x가 zero vector가 아닌 경우에 식을 만족하는 벡터 x를 찾아야함

# %% [markdown]
# 주어진 matrix![image.png](attachment:image.png)
#
# linearly dependent한 column을 가질 때 non trivial한 solution x가 eigen vector가 된다
#
# linearly dependent: vector를 추가하는데 추가된 벡터가 기존 span범위 내에 포함되어 span 범위를 늘려주지 않음

# %% [markdown]
# linearly independent한 column의 경우
# ![image.png](attachment:image.png)
# x에 해당하는 solution은 0벡터밖에 없음
#
# 주어진 matrix A에 람다I를 빼면 결과적으로 나오는 matrix는 linearly dependent한 column으로 나오게 된다
#
# 이처럼 linearly independent한 matrix도 잘 조절하여 linearly dependent한 column으로 만들어주는 것이 eigenvector나 value를 구하는 과정이다

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# 결과적으로 같은 line 선상의 벡터로 바뀌게 되어 linearly dependent한 column이 되었으며, x는 non trivial한 solution이 나오게 된다
#
# ![image.png](attachment:image.png)
#
# x에 1이 들어간 2차원 벡터가 되면 둘이 더해지면서 0벡터가 만들어진다

# %% [markdown]
# c: 아무 상수나 쓸 수 있다
# (5, 5) 역시 식을 만족하는 eigen vector이다
